# %% [markdown]
# # Design patterns

# %% [markdown]
# Now we have completed a very simple but fully functional pipeline, let's revisit some design patterns that were used in your pipeline and will commonly occur in the future pipeline you would design.

# %% [markdown]
# As always, let's start by importing DataJoint package. Also, import all the tables by importing them from the `session3.py` module.

# %%
import datajoint as dj
from session2 import schema, Mouse, Session

# %% [markdown]
# ## Experimental subjects as the root of your schema

# %% [markdown]
# Let's take a look at our pipeline's ERD again

# %%
dj.ERD(schema)

# %% [markdown]
# And note that `Mouse` table is at the very top of the ERD. Now take a look at a working pipeline available to you as `b

# %%
import calcium

# %%
calcium.Segmentation()
# Out:
# *mouse_id    *session    *scan_idx    *slice    *channel    *segmentation_ segmentation_t
# +----------+ +---------+ +----------+ +-------+ +---------+ +------------+ +------------+
# 8623         1           5            1         1           2              2018-01-10 02:
# 8623         1           5            2         1           2              2018-01-10 02:
# 8623         1           5            3         1           2              2018-01-10 02:
# 8804         1           3            1         1           2              2018-01-10 02:
# 8804         1           3            2         1           2              2018-01-10 02:
# 8804         1           3            3         1           2              2018-01-10 02:
#  (6 tuples)

# %%
dj.ERD(calcium)

# %% [markdown]
# ## One-to-many relationships

# %% [markdown]
# ## Many-to-many relationships

# %% [markdown]
# ## Lookup tables to hold parameters for analysis/processing

# %% [markdown]
# ## Indication of data presence/absence via table entry

# %% [markdown]
# # Advanced query examples

# %% [markdown]
# Give me all mouse for which receptive fields (RF) have been calculated.

# %% [markdown]
# Give me all scans for which we also recorded running data
